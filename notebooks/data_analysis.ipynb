# %%
# FreshRetailNet-50K Data Analysis

This notebook analyzes the preprocessed data and creates visualizations for key insights.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sqlalchemy import create_engine, text
from dotenv import load_dotenv

# Set plotting style
plt.style.use("seaborn")
sns.set_palette("husl")

# Load environment variables
load_dotenv()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Forecasting/venv/lib/python3.9/site-packages/matplotlib/style/core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File ~/Forecasting/venv/lib/python3.9/site-packages/matplotlib/__init__.py:873, in _rc_params_in_file(fname, transform, fail_on_error)
#     872 rc_temp = {}
# --> 873 with _open_file_or_url(fname) as fd:
#     874     try:
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:117, in _GeneratorContextManager.__enter__(self)
#     116 try:
# --> 117     return next(self.gen)
#     118 except StopIteration:
#
# File ~/Forecasting/venv/lib/python3.9/site-packages/matplotlib/__init__.py:850, in _open_file_or_url(fname)
#     849 fname = os.path.expanduser(fname)
# --> 850 with open(fname, encoding='utf-8') as f:
#     851     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 11
#       8 from dotenv import load_dotenv
#      10 # Set plotting style
# ---> 11 plt.style.use('seaborn')
#      12 sns.set_palette("husl")
#      14 # Load environment variables
#
# File ~/Forecasting/venv/lib/python3.9/site-packages/matplotlib/style/core.py:139, in use(style)
#     137         style = _rc_params_in_file(style)
#     138     except OSError as err:
# --> 139         raise OSError(
#     140             f"{style!r} is not a valid package style, path of style "
#     141             f"file, URL of style file, or library style name (library "
#     142             f"styles are listed in `style.available`)") from err
#     143 filtered = {}
#     144 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'seaborn' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)
